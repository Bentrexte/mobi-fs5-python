# %% [markdown]
# # [Lab Session 1](segm_threshold.ipynb)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **[Task 1.2 (a).]()** Use `plt.imread` to load an image:

# %%
a = plt.imread('data/NIH3T3/im/dna-0.png')

# %% [markdown]
# **[Task 1.2 (b).]()** Show the image:

# %%
plt.figure()
plt.imshow(a)
plt.colorbar()

# %% [markdown]
# **[Task 1.2 (d).]()** Binarize the image by applying an intensity threshold:

# %%
plt.hist(a)
plt.show()

T = 0.1

a = a < T
plt.figure()
plt.imshow(a, cmap = 'grey')
plt.colorbar()

# %% [markdown]
# **[Task 1.2 (e).]()** Load the ground truth:

# %%
b = plt.imread('data/NIH3T3/gt/0.png')
plt.figure()
plt.imshow(b)
plt.colorbar()

# %% [markdown]
# Compute and print the Dice coefficient:
